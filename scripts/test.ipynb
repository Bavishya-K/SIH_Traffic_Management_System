# %%
import numpy as np
import tensorflow as tf
from collections import deque
from traffic_count_detection import get_vehicle_counts
from emergency_detection import detect_emergency
from accident_detection import detect_accident

# Load the trained RL model
model = tf.keras.models.load_model("../models/rl_trained_model.keras")

# Phase encoding with four traffic phases
PHASE_ENCODING = {
    0: [1, 0, 0, 0],  # North-South Straight
    1: [0, 1, 0, 0],  # East-West Straight
    2: [0, 0, 1, 0],  # North-South Left Turn
    3: [0, 0, 0, 1],  # East-West Left Turn
}

def get_state(in_counts, out_counts, emergency, accident, queue_length, current_phase, phase_history, neighbor_state):
    in_counts = [count / 10.0 for count in in_counts]
    out_counts = [count / 10.0 for count in out_counts]
    neighbor_state = [count / 10.0 for count in neighbor_state]

    state = []
    state.extend(in_counts)
    state.extend(out_counts)
    state.extend([emergency, accident, queue_length])
    state.extend(PHASE_ENCODING[current_phase])
    state.extend(np.array(phase_history).flatten())  # Flatten phase history
    state.extend(neighbor_state)
    return np.array(state, dtype=np.float32)

def act(state, model):
    state = state.reshape(1, -1)
    q_values = model.predict(state, verbose=0)
    return np.argmax(q_values[0])

def get_inputs():
    video_paths = [
        '../videos/count/count_2.mp4',
        '../videos/count/count_4.mp4',
        '../videos/count/count_6.mp4',
        '../videos/count/count_7.mp4'
    ]

    in_counts = []
    out_counts = []
    emergency_detected = False
    accident_detected = False

    for path in video_paths:
        in_count, out_count = get_vehicle_counts(path, duration=20)
        in_counts.append(in_count)
        out_counts.append(out_count)

        if detect_emergency(path):
            emergency_detected = True

        if detect_accident(path):
            accident_detected = True

    emergency = 1 if emergency_detected else 0
    accident = 1 if accident_detected else 0
    queue_length = sum(in_counts) - sum(out_counts)
    neighbor_state = [0] * 8  # Placeholder for neighbor data

    return in_counts, out_counts, emergency, accident, queue_length, neighbor_state

def change_phase(phase):
    phases = [
        "North-South Straight Traffic Green",
        "East-West Straight Traffic Green",
        "North-South Left Turn Green",
        "East-West Left Turn Green"
    ]
    print(f"Changing to: {phases[phase]}")

def main_inference():
    phase_history = deque([[0, 0, 0, 0] for _ in range(3)], maxlen=3)
    current_phase = 0

    # Process input data once
    in_counts, out_counts, emergency, accident, queue_length, neighbor_state = get_inputs()

    # Prepare the state for RL model
    state = get_state(
        in_counts, out_counts, emergency, accident, queue_length,
        current_phase, phase_history, neighbor_state
    )

    # Predict the next phase
    next_phase = act(state, model)
    change_phase(next_phase)

if __name__ == "__main__":
    main_inference()
# Out:
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 58.2ms
# Speed: 10.5ms preprocess, 58.2ms inference, 99.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 8 cars, 4 motorcycles, 1 traffic light, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 5.9ms
# Speed: 4.4ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 4 motorcycles, 1 traffic light, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 8 cars, 4 motorcycles, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 11.3ms
# Speed: 6.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 14.3ms
# Speed: 0.6ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 16.7ms
# Speed: 2.9ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 2 motorcycles, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 17.6ms
# Speed: 0.6ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 3.2ms
# Speed: 5.2ms preprocess, 3.2ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 11.2ms
# Speed: 0.3ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 3 motorcycles, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 9.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 1 truck, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 6.6ms
# Speed: 6.3ms preprocess, 6.6ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 13.8ms
# Speed: 0.0ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 2 motorcycles, 6.8ms
# Speed: 5.8ms preprocess, 6.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 1 motorcycle, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 14.2ms
# Speed: 1.4ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 12.1ms
# Speed: 4.2ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4.0ms
# Speed: 2.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 7 cars, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 10.5ms
# Speed: 5.9ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 4.0ms
# Speed: 2.1ms preprocess, 4.0ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 1 motorcycle, 11.9ms
# Speed: 4.5ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 1 motorcycle, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 3.4ms
# Speed: 1.7ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 1 motorcycle, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 3.4ms
# Speed: 6.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 4 motorcycles, 2.3ms
# Speed: 3.6ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 4.0ms
# Speed: 4.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 5.5ms
# Speed: 0.0ms preprocess, 5.5ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 2 motorcycles, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 2 motorcycles, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 2 trucks, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 2 trucks, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 5 motorcycles, 1 truck, 7.1ms
# Speed: 0.0ms preprocess, 7.1ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 4 motorcycles, 1 truck, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 1 truck, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 3 motorcycles, 1 truck, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 3 motorcycles, 2 trucks, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 3 motorcycles, 1 truck, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 3 motorcycles, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 10.7ms
# Speed: 4.8ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 2 trucks, 4.8ms
# Speed: 1.7ms preprocess, 4.8ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 3 motorcycles, 1 truck, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 2 motorcycles, 1 truck, 6.3ms
# Speed: 0.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 2.4ms
# Speed: 3.7ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 2 trucks, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 2 trucks, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 3 motorcycles, 1 truck, 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 9.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 4.5ms
# Speed: 2.0ms preprocess, 4.5ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 3 motorcycles, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 4.0ms
# Speed: 2.4ms preprocess, 4.0ms inference, 9.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 3.6ms
# Speed: 6.0ms preprocess, 3.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 16.6ms
# Speed: 6.5ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 10.4ms
# Speed: 8.2ms preprocess, 10.4ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 4 motorcycles, 4.0ms
# Speed: 4.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 5 motorcycles, 9.6ms
# Speed: 6.9ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 6 cars, 5 motorcycles, 6.7ms
# Speed: 4.6ms preprocess, 6.7ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 6 motorcycles, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 7 cars, 4 motorcycles, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 7 cars, 4 motorcycles, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 7 cars, 5 motorcycles, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 5 motorcycles, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 5 motorcycles, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 5 motorcycles, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 5 motorcycles, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 6 motorcycles, 17.0ms
# Speed: 2.5ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 5 motorcycles, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 4.6ms
# Speed: 3.4ms preprocess, 4.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 5 motorcycles, 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 5 motorcycles, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 3 motorcycles, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 3 motorcycles, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 4 motorcycles, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 13.3ms
# Speed: 0.0ms preprocess, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 1 truck, 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 6.9ms
# Speed: 5.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 11.9ms
# Speed: 0.3ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 2 motorcycles, 8.9ms
# Speed: 4.5ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 4 motorcycles, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 5.3ms
# Speed: 5.8ms preprocess, 5.3ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 1 truck, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 1 truck, 4.8ms
# Speed: 4.1ms preprocess, 4.8ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 4 motorcycles, 1 truck, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 4.0ms
# Speed: 4.7ms preprocess, 4.0ms inference, 8.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 1 truck, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 1 truck, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 2.7ms
# Speed: 3.4ms preprocess, 2.7ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 3.4ms
# Speed: 6.6ms preprocess, 3.4ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 motorcycle, 1 truck, 16.4ms
# Speed: 0.5ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 motorcycle, 4.0ms
# Speed: 4.9ms preprocess, 4.0ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 1 truck, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 1 motorcycle, 1 truck, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 trucks, 24.5ms
# Speed: 2.8ms preprocess, 24.5ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 1 motorcycle, 2 trucks, 17.7ms
# Speed: 6.4ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 2 trucks, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 1 motorcycle, 1 truck, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 1 truck, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 1 truck, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 1 truck, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 truck, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 truck, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 truck, 15.5ms
# Speed: 6.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 truck, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 11.7ms
# Speed: 2.7ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 motorcycle, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 motorcycles, 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 motorcycle, 14.7ms
# Speed: 0.4ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 13.3ms
# Speed: 0.0ms preprocess, 13.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 6.0ms
# Speed: 5.7ms preprocess, 6.0ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 truck, 16.9ms
# Speed: 2.3ms preprocess, 16.9ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 14.6ms
# Speed: 0.1ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 11.7ms
# Speed: 6.7ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 11.8ms
# Speed: 0.6ms preprocess, 11.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 15.4ms
# Speed: 1.4ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 trucks, 11.4ms
# Speed: 4.0ms preprocess, 11.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 2 trucks, 15.9ms
# Speed: 0.2ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 14.9ms
# Speed: 0.8ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 6.5ms
# Speed: 3.9ms preprocess, 6.5ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 13.5ms
# Speed: 4.8ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 11.5ms
# Speed: 2.9ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 11.8ms
# Speed: 0.7ms preprocess, 11.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 11.6ms
# Speed: 5.0ms preprocess, 11.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 12.5ms
# Speed: 0.7ms preprocess, 12.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 34.8ms
# Speed: 4.3ms preprocess, 34.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 skateboard, 13.8ms
# Speed: 0.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 5.0ms
# Speed: 5.2ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 12.6ms
# Speed: 5.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 16.9ms
# Speed: 3.2ms preprocess, 16.9ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 11.9ms
# Speed: 4.6ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 11.3ms
# Speed: 4.8ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 10.1ms
# Speed: 6.3ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 11.8ms
# Speed: 4.1ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 10.5ms
# Speed: 6.1ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 17.7ms
# Speed: 1.5ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 11.2ms
# Speed: 4.2ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 motorcycle, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 19.5ms
# Speed: 0.0ms preprocess, 19.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 motorcycle, 13.7ms
# Speed: 4.0ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 motorcycles, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 traffic light, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 traffic light, 4.4ms
# Speed: 5.7ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 traffic light, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 13.7ms
# Speed: 0.8ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 11.6ms
# Speed: 3.7ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 8 cars, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 8 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 3.8ms
# Speed: 5.3ms preprocess, 3.8ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 traffic light, 12.6ms
# Speed: 1.7ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 traffic light, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 traffic light, 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 motorcycle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 traffic light, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 traffic light, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 traffic light, 4.6ms
# Speed: 3.9ms preprocess, 4.6ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 traffic light, 13.1ms
# Speed: 5.1ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 traffic light, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 traffic light, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 traffic light, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 traffic light, 5.9ms
# Speed: 3.7ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 1 traffic light, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 10.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 1 traffic light, 2.5ms
# Speed: 7.7ms preprocess, 2.5ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 1 traffic light, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 1 traffic light, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 truck, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 1 truck, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 1 truck, 1 traffic light, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 truck, 1 traffic light, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 truck, 1 traffic light, 2.4ms
# Speed: 6.3ms preprocess, 2.4ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 1 truck, 1 traffic light, 3.6ms
# Speed: 2.2ms preprocess, 3.6ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 1 traffic light, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 truck, 1 traffic light, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 1 truck, 4.5ms
# Speed: 2.3ms preprocess, 4.5ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 1 truck, 4.9ms
# Speed: 5.1ms preprocess, 4.9ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 1 truck, 3.5ms
# ...
#
# 0: 384x640 1 noaccident, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.1ms
# Speed: 5.3ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 14.9ms
# Speed: 5.4ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.0ms
# Speed: 8.5ms preprocess, 10.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 21.9ms
# Speed: 7.6ms preprocess, 21.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 16.6ms
# Speed: 7.3ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 8.4ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 8.5ms preprocess, 17.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 6.8ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 4.5ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 13.7ms
# Speed: 6.7ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 4.6ms preprocess, 16.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 30.9ms
# Speed: 2.3ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 25.3ms
# Speed: 6.9ms preprocess, 25.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 4.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 11.1ms
# Speed: 12.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.6ms
# Speed: 8.3ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 13.4ms preprocess, 15.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 6.1ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.1ms
# Speed: 2.7ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 5.8ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 12.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 10.2ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 3.6ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 3.6ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.8ms
# Speed: 7.5ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.5ms
# Speed: 9.8ms preprocess, 18.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 5.1ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 7.7ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.6ms
# Speed: 6.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 8.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.5ms
# Speed: 3.7ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 11.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 9.3ms preprocess, 16.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 8.3ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 0.0ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 8.7ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 1.5ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.5ms
# Speed: 5.1ms preprocess, 12.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 7.9ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 3.4ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.3ms
# Speed: 4.6ms preprocess, 12.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 8.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 8.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.2ms
# Speed: 5.4ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.6ms
# Speed: 5.5ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 7.5ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 6.5ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.2ms
# Speed: 4.0ms preprocess, 22.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 8.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 8.3ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 14.9ms
# Speed: 8.4ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 8.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 16.2ms
# Speed: 8.1ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.8ms
# Speed: 11.1ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 25.6ms
# Speed: 4.9ms preprocess, 25.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 20.4ms
# Speed: 15.0ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 27.9ms
# Speed: 3.8ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 6.8ms
# Speed: 8.0ms preprocess, 6.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 17.1ms
# Speed: 13.2ms preprocess, 17.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 17.2ms
# Speed: 9.8ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.9ms
# Speed: 6.0ms preprocess, 10.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.3ms
# Speed: 10.0ms preprocess, 15.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 16.1ms
# Speed: 7.7ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.5ms
# Speed: 8.3ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 12.8ms
# Speed: 5.8ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 17.6ms
# Speed: 9.7ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 14.8ms
# Speed: 3.5ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 36.0ms
# Speed: 4.8ms preprocess, 36.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.4ms
# Speed: 6.7ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 11.1ms
# Speed: 7.1ms preprocess, 11.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.1ms
# Speed: 8.4ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 12.1ms
# Speed: 11.0ms preprocess, 12.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 13.4ms
# Speed: 5.1ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 14.8ms
# Speed: 5.8ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 12.7ms
# Speed: 5.7ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 9.1ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 13.0ms
# Speed: 7.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.1ms
# Speed: 5.1ms preprocess, 10.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 6.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.2ms
# Speed: 10.1ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 6.5ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 3.9ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 10.4ms preprocess, 10.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 8.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Changing to: North-South Left Turn Green

# %%
from concurrent.futures import ThreadPoolExecutor
import numpy as np
import tensorflow as tf
from collections import deque
from traffic_count_detection import get_vehicle_counts
from emergency_detection import detect_emergency
from accident_detection import detect_accident

model = tf.keras.models.load_model("../models/rl_trained_model.keras")

PHASE_ENCODING = {0: [1, 0, 0, 0], 1: [0, 1, 0, 0], 2: [0, 0, 1, 0], 3: [0, 0, 0, 1]}

def get_state(in_counts, out_counts, emergency, accident, queue_length, current_phase, phase_history, neighbor_state):
    in_counts = [count / 10.0 for count in in_counts]
    out_counts = [count / 10.0 for count in out_counts]
    neighbor_state = [count / 10.0 for count in neighbor_state]

    state = []
    state.extend(in_counts)
    state.extend(out_counts)
    state.extend([emergency, accident, queue_length])
    state.extend(PHASE_ENCODING[current_phase])
    state.extend(np.array(phase_history).flatten())
    state.extend(neighbor_state)
    return np.array(state, dtype=np.float32)

def act(state, model):
    state = state.reshape(1, -1)
    q_values = model.predict(state, verbose=0)
    return np.argmax(q_values[0])

def process_models(video_path):
    with ThreadPoolExecutor(max_workers=3) as executor:
        vehicle_future = executor.submit(get_vehicle_counts, video_path, 20)
        emergency_future = executor.submit(detect_emergency, video_path)
        accident_future = executor.submit(detect_accident, video_path)

        in_count, out_count = vehicle_future.result()
        emergency = emergency_future.result()
        accident = accident_future.result()

    return in_count, out_count, int(emergency), int(accident)

def get_inputs():
    video_paths = [
        '../videos/count/count_2.mp4',
        '../videos/count/count_4.mp4',
        '../videos/count/count_6.mp4',
        '../videos/count/count_7.mp4'
    ]

    results = []
    for path in video_paths:
        results.append(process_models(path))

    in_counts, out_counts, emergency, accident = [], [], False, False

    for in_count, out_count, emergency_flag, accident_flag in results:
        in_counts.append(in_count)
        out_counts.append(out_count)
        emergency |= emergency_flag
        accident |= accident_flag

    queue_length = max(0, sum(in_counts) - sum(out_counts))
    neighbor_state = [0] * 8
    return in_counts, out_counts, emergency, accident, queue_length, neighbor_state

def change_phase(phase):
    phases = [
        "North-South Straight Traffic Green",
        "East-West Straight Traffic Green",
        "North-South Left Turn Green",
        "East-West Left Turn Green"
    ]
    print(f"Changing to: {phases[phase]}")

def main_inference():
    phase_history = deque([[0, 0, 0, 0] for _ in range(3)], maxlen=3)
    current_phase = 0

    in_counts, out_counts, emergency, accident, queue_length, neighbor_state = get_inputs()

    state = get_state(
        in_counts, out_counts, emergency, accident, queue_length, current_phase, phase_history, neighbor_state
    )

    next_phase = act(state, model)
    change_phase(next_phase)

if __name__ == "__main__":
    main_inference()
# Out:
# 0: 384x640 1 noaccident, 80.4ms
# Speed: 0.0ms preprocess, 80.4ms inference, 100.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 204.4ms
# Speed: 10.0ms preprocess, 204.4ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 212.4ms
# Speed: 10.0ms preprocess, 212.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 20.4ms
# Speed: 8.5ms preprocess, 20.4ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 29.0ms
# 0: 384x640 1 ER, 20.5ms
#
# Speed: 5.5ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.8ms preprocess, 20.5ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 8 cars, 4 motorcycles, 1 traffic light, 31.7ms
# Speed: 0.0ms preprocess, 31.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 27.8ms
# Speed: 0.0ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 noaccidents, 27.8ms
# Speed: 0.0ms preprocess, 27.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 384x640 1 ER, 24.8ms
# Speed: 0.0ms preprocess, 24.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 noaccidents, 29.4ms
# Speed: 4.5ms preprocess, 29.4ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 29.9ms
# Speed: 2.8ms preprocess, 29.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 1 traffic light, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 33.5ms
#
# Speed: 10.7ms preprocess, 33.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 32.6ms
# Speed: 1.4ms preprocess, 32.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 28.5ms
# Speed: 1.3ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 3 persons, 7 cars, 4 motorcycles, 1 traffic light, 24.6ms
#
# Speed: 0.0ms preprocess, 24.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 8 cars, 4 motorcycles, 30.0ms
# Speed: 8.3ms preprocess, 30.0ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 33.2ms
# Speed: 4.0ms preprocess, 33.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 37.1ms
# Speed: 0.0ms preprocess, 37.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 33.1ms
# Speed: 0.0ms preprocess, 33.1ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 33.1ms
# Speed: 0.3ms preprocess, 33.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 37.3ms
# Speed: 0.0ms preprocess, 37.3ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 41.1ms
# Speed: 4.0ms preprocess, 41.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 29.6ms
# Speed: 4.0ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 33.1ms
# Speed: 0.0ms preprocess, 33.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 24.2ms
# Speed: 0.2ms preprocess, 24.2ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 20.3ms
# Speed: 3.9ms preprocess, 20.3ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 27.8ms
# 0: 384x640 2 noaccidents, 27.8ms
# Speed: 0.0ms preprocess, 27.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
# Speed: 0.0ms preprocess, 27.8ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 25.7ms
# Speed: 0.1ms preprocess, 25.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 6.1ms preprocess, 24.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 2 motorcycles, 30.4ms
# Speed: 4.5ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 30.3ms
# Speed: 3.0ms preprocess, 30.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.3ms
# Speed: 2.9ms preprocess, 28.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 34.8ms
# Speed: 4.7ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 26.1ms
# Speed: 1.6ms preprocess, 26.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 48.1ms
# Speed: 2.4ms preprocess, 48.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 30.7ms
# Speed: 2.5ms preprocess, 30.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 40.2ms
# Speed: 4.5ms preprocess, 40.2ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 30.2ms
# Speed: 2.8ms preprocess, 30.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 noaccidents, 34.5ms
# Speed: 0.0ms preprocess, 34.5ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 32.1ms
# Speed: 2.6ms preprocess, 32.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 29.9ms
# Speed: 0.0ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 33.3ms
# Speed: 0.0ms preprocess, 33.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 33.8ms
# Speed: 0.0ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 38.7ms
# Speed: 0.0ms preprocess, 38.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 29.3ms
# Speed: 0.0ms preprocess, 29.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 5 cars, 3 motorcycles, 21.3ms
# Speed: 8.0ms preprocess, 21.3ms inference, 13.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 27.6ms
# Speed: 11.4ms preprocess, 27.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 30.4ms
# Speed: 5.9ms preprocess, 30.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 22.2ms
# Speed: 6.7ms preprocess, 22.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 25.4ms
# Speed: 7.0ms preprocess, 25.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 31.1ms
# Speed: 0.0ms preprocess, 31.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 35.3ms
# Speed: 0.0ms preprocess, 35.3ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 24.2ms
# Speed: 3.2ms preprocess, 24.2ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ER, 33.1ms
# Speed: 0.0ms preprocess, 33.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 noaccidents, 43.3ms
# Speed: 0.0ms preprocess, 43.3ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 38.2ms
# Speed: 0.0ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 1 truck, 17.8ms
# Speed: 5.1ms preprocess, 17.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 30.3ms
# Speed: 0.0ms preprocess, 30.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 30.1ms
# Speed: 3.3ms preprocess, 30.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 7 cars, 2 motorcycles, 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 28.7ms
# Speed: 7.5ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 22.9ms
# Speed: 0.0ms preprocess, 22.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 20.5ms
#
# Speed: 6.2ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 7 cars, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 14.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 6.0ms
# Speed: 4.5ms preprocess, 6.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 7 cars, 1 motorcycle, 27.4ms
# Speed: 0.0ms preprocess, 27.4ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 20.4ms
# Speed: 7.0ms preprocess, 20.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 7 cars, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 43.9ms
# Speed: 0.0ms preprocess, 43.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 2 persons, 6 cars, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 9.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 6 cars, 17.4ms
# Speed: 6.4ms preprocess, 17.4ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 30.3ms
# Speed: 4.0ms preprocess, 30.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 25.9ms
# Speed: 0.0ms preprocess, 25.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 25.2ms
# Speed: 1.6ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 7 cars, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 7 cars, 19.6ms
# Speed: 3.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 7 cars, 16.6ms
# Speed: 5.3ms preprocess, 16.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 7 cars, 10.8ms
# Speed: 6.0ms preprocess, 10.8ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 27.4ms
#
# Speed: 0.0ms preprocess, 27.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 7 cars, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 5 persons, 7 cars, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 28.7ms
# Speed: 8.3ms preprocess, 28.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 5 persons, 7 cars, 16.0ms
# Speed: 7.1ms preprocess, 16.0ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 29.2ms
# Speed: 0.7ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 6 persons, 7 cars, 21.1ms
# Speed: 0.7ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 6 cars, 22.4ms
# Speed: 4.4ms preprocess, 22.4ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 30.3ms
# Speed: 0.0ms preprocess, 30.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 21.5ms
# Speed: 2.4ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 23.5ms
# Speed: 5.0ms preprocess, 23.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 1 motorcycle, 16.7ms
# Speed: 5.2ms preprocess, 16.7ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 22.7ms
# Speed: 4.3ms preprocess, 22.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 1 motorcycle, 27.4ms
# Speed: 0.0ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 35.0ms
# Speed: 0.0ms preprocess, 35.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 8.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 29.5ms
# Speed: 1.5ms preprocess, 29.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 1 motorcycle, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 23.7ms
# Speed: 0.0ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 19.5ms
# Speed: 7.1ms preprocess, 19.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 32.4ms
# Speed: 0.0ms preprocess, 32.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 18.8ms
# Speed: 0.0ms preprocess, 18.8ms inference, 8.8ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 13.6ms
# Speed: 4.0ms preprocess, 13.6ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 40.8ms
#
# Speed: 0.0ms preprocess, 40.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 20.5ms
# Speed: 6.1ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 16.3ms
# Speed: 6.5ms preprocess, 16.3ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 4 motorcycles, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 16.9ms
# Speed: 4.8ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 30.8ms
# Speed: 0.0ms preprocess, 30.8ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 2 noaccidents, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 4 cars, 2 motorcycles, 18.5ms
# Speed: 5.4ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 20.9ms
# Speed: 8.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 10.0ms
# Speed: 8.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 2 motorcycles, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 2 trucks, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 18.5ms
# Speed: 1.8ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 2 trucks, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 19.9ms
# Speed: 3.5ms preprocess, 19.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 3 cars, 5 motorcycles, 1 truck, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 8.4ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 4 persons, 3 cars, 4 motorcycles, 1 truck, 20.1ms
#
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 noaccidents, 17.7ms
# Speed: 6.3ms preprocess, 17.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 32.8ms
# Speed: 4.3ms preprocess, 32.8ms inference, 10.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 1 truck, 32.6ms
# Speed: 0.0ms preprocess, 32.6ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 23.0ms
# Speed: 6.0ms preprocess, 23.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 4 cars, 3 motorcycles, 1 truck, 28.1ms
# Speed: 3.5ms preprocess, 28.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 3 cars, 3 motorcycles, 2 trucks, 18.4ms
# Speed: 3.4ms preprocess, 18.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 31.8ms
#
# Speed: 2.2ms preprocess, 31.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 2 cars, 3 motorcycles, 1 truck, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 30.1ms
# Speed: 8.5ms preprocess, 30.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 3 noaccidents, 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 3 cars, 4 motorcycles, 11.5ms
# Speed: 4.7ms preprocess, 11.5ms inference, 10.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 4 cars, 3 motorcycles, 16.6ms
# Speed: 3.6ms preprocess, 16.6ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 18.8ms
# Speed: 0.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 27.3ms
# Speed: 5.6ms preprocess, 27.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 16.8ms
# Speed: 4.2ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 26.5ms
# Speed: 7.5ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 20.7ms
# Speed: 6.0ms preprocess, 20.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 2 noaccidents, 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 2 trucks, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 5 cars, 3 motorcycles, 1 truck, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 20.6ms
# Speed: 6.4ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 18.4ms
# Speed: 8.0ms preprocess, 18.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 7 cars, 2 motorcycles, 1 truck, 18.8ms
# Speed: 2.7ms preprocess, 18.8ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 20.6ms
# Speed: 6.4ms preprocess, 20.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 23.2ms
# Speed: 0.0ms preprocess, 23.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 2 trucks, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 2 trucks, 16.8ms
# Speed: 2.3ms preprocess, 16.8ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 22.7ms
# Speed: 0.0ms preprocess, 22.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 18.7ms
# Speed: 9.4ms preprocess, 18.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 18.1ms
# Speed: 3.7ms preprocess, 18.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 4 cars, 3 motorcycles, 1 truck, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 19.4ms
# Speed: 0.0ms preprocess, 19.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 noaccidents, 18.4ms
# Speed: 7.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 9.9ms
#
# Speed: 7.0ms preprocess, 9.9ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 31.5ms
# 0: 320x640 3 persons, 4 cars, 3 motorcycles, 25.0ms
# Speed: 1.6ms preprocess, 31.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 0.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 20.9ms
# Speed: 1.8ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 39.0ms
# Speed: 7.5ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 22.9ms
# Speed: 4.0ms preprocess, 22.9ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 24.6ms
# Speed: 2.8ms preprocess, 24.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 23.7ms
# Speed: 0.4ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 29.8ms
# Speed: 0.6ms preprocess, 29.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 26.5ms
# Speed: 0.0ms preprocess, 26.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 7 cars, 4 motorcycles, 19.9ms
# Speed: 2.1ms preprocess, 19.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 27.6ms
# Speed: 0.0ms preprocess, 27.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 7 cars, 5 motorcycles, 24.2ms
# Speed: 0.0ms preprocess, 24.2ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 28.3ms
# Speed: 3.0ms preprocess, 28.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 6 persons, 6 cars, 5 motorcycles, 18.0ms
# Speed: 1.6ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 (no detections), 30.2ms
# Speed: 5.8ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 3.3ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 6 motorcycles, 18.7ms
# Speed: 0.7ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 (no detections), 9.2ms
# Speed: 8.1ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 19.9ms
# Speed: 2.9ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 6 persons, 7 cars, 4 motorcycles, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 15.2ms
# Speed: 6.1ms preprocess, 15.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 6 persons, 7 cars, 4 motorcycles, 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 6 persons, 7 cars, 5 motorcycles, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 5 persons, 7 cars, 5 motorcycles, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 noaccident, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 6 cars, 4 motorcycles, 20.0ms
# Speed: 3.7ms preprocess, 20.0ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 23.3ms
# Speed: 1.9ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 28.4ms
# Speed: 0.0ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 20.4ms
# Speed: 3.5ms preprocess, 20.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 18.9ms
# Speed: 0.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 36.4ms
# Speed: 0.0ms preprocess, 36.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 17.2ms
# Speed: 5.5ms preprocess, 17.2ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 33.3ms
# Speed: 8.6ms preprocess, 33.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 5 cars, 5 motorcycles, 22.1ms
# Speed: 4.3ms preprocess, 22.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 accident, 29.9ms
# Speed: 0.0ms preprocess, 29.9ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 32.0ms
# Speed: 2.9ms preprocess, 32.0ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 28.1ms
# Speed: 13.1ms preprocess, 28.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 6.7ms preprocess, 20.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 19.2ms
#
# Speed: 1.5ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 5 motorcycles, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 4 persons, 4 cars, 5 motorcycles, 15.0ms
# Speed: 5.5ms preprocess, 15.0ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 24.7ms
# Speed: 8.0ms preprocess, 24.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 3 persons, 6 cars, 6 motorcycles, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 noaccident, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 5 persons, 4 cars, 5 motorcycles, 16.6ms
# Speed: 2.8ms preprocess, 16.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 21.3ms
# Speed: 3.5ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 18.6ms
#
# Speed: 0.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 1 noaccident, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 4 cars, 5 motorcycles, 16.8ms
# Speed: 6.1ms preprocess, 16.8ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 1 noaccident, 25.9ms
# Speed: 0.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 accident, 1 noaccident, 20.2ms
# Speed: 10.1ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 5 motorcycles, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 accident, 1 noaccident, 27.6ms
# Speed: 0.0ms preprocess, 27.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 26.7ms
# Speed: 0.0ms preprocess, 26.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 accident, 1 noaccident, 29.8ms
# Speed: 6.8ms preprocess, 29.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 4 cars, 3 motorcycles, 17.1ms
# Speed: 3.5ms preprocess, 17.1ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 accident, 1 noaccident, 8.5ms
# Speed: 6.5ms preprocess, 8.5ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 4 cars, 3 motorcycles, 16.0ms
# Speed: 4.7ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 accident, 1 noaccident, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 4 cars, 4 motorcycles, 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 accident, 1 noaccident, 19.6ms
#
# Speed: 2.3ms preprocess, 19.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 16.4ms
# Speed: 2.8ms preprocess, 16.4ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 21.5ms
#
# Speed: 3.5ms preprocess, 21.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 18.1ms
# Speed: 6.5ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 22.8ms
# Speed: 0.0ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 19.2ms
#
# Speed: 3.5ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 18.0ms
# Speed: 8.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 22.0ms
# Speed: 2.9ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 23.7ms
# Speed: 0.0ms preprocess, 23.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 1 truck, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 23.2ms
# Speed: 2.6ms preprocess, 23.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 19.1ms
# Speed: 5.2ms preprocess, 19.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 2 noaccidents, 26.9ms
#
# Speed: 0.0ms preprocess, 26.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 17.8ms
# Speed: 4.0ms preprocess, 17.8ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 22.5ms
# Speed: 5.0ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 19.2ms
# Speed: 5.0ms preprocess, 19.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 3 persons, 6 cars, 2 motorcycles, 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 1 person, 6 cars, 4 motorcycles, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 25.3ms
# Speed: 10.9ms preprocess, 25.3ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 27.6ms
# Speed: 9.5ms preprocess, 27.6ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 3 noaccidents, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 28.7ms
# Speed: 0.0ms preprocess, 28.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 20.5ms
# Speed: 5.8ms preprocess, 20.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 noaccidents, 33.9ms
# Speed: 0.0ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 1 truck, 17.2ms
# ...
# 0: 384x640 (no detections), 70.5ms
# Speed: 10.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 320x640 2 cars, 1 truck, 30.8ms
# Speed: 10.0ms preprocess, 30.8ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 30.9ms
# Speed: 0.0ms preprocess, 30.9ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 30.7ms
# Speed: 10.3ms preprocess, 30.7ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 320x640 2 cars, 1 truck, 40.7ms
# Speed: 0.0ms preprocess, 40.7ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 60.5ms
# Speed: 10.3ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 60.3ms
# Speed: 10.2ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 10.5ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 noaccident, 50.9ms
# Speed: 10.3ms preprocess, 50.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 20.4ms postprocess per image at shape (1, 3, 320, 640)
#
#
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 noaccident, 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 50.9ms
# Speed: 10.4ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 (no detections), 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 70.0ms
# Speed: 10.3ms preprocess, 70.0ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.5ms
# Speed: 10.0ms preprocess, 30.5ms inference, 10.3ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 (no detections), 30.4ms
#
# Speed: 10.5ms preprocess, 30.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 50.9ms
# Speed: 10.0ms preprocess, 50.9ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 (no detections), 60.8ms
# Speed: 0.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.0ms
# Speed: 10.1ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 2 cars, 1 truck, 30.7ms
# Speed: 0.0ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 0.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 noaccident, 30.4ms
# Speed: 20.0ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 40.2ms
# Speed: 10.4ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 cars, 1 truck, 40.1ms
# Speed: 10.1ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 noaccident, 30.2ms
# Speed: 0.0ms preprocess, 30.2ms inference, 40.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 30.2ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 cars, 1 truck, 31.1ms
# Speed: 0.0ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 30.2ms
# Speed: 0.0ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.3ms
# Speed: 10.0ms preprocess, 30.3ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 320x640 2 cars, 1 truck, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 noaccident, 30.7ms
# Speed: 0.0ms preprocess, 30.7ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 60.9ms
# Speed: 0.0ms preprocess, 60.9ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 (no detections), 50.9ms
# Speed: 10.0ms preprocess, 50.9ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 384x640 1 ER, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 51.1ms
# Speed: 10.0ms preprocess, 51.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 51.1ms
# Speed: 10.0ms preprocess, 51.1ms inference, 10.3ms postprocess per image at shape (1, 3, 320, 640)
#
#
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 10.2ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 10.0ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 ERs, 40.4ms
# Speed: 0.0ms preprocess, 40.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.2ms
# Speed: 10.0ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
#
# 0: 384x640 (no detections), 51.4ms
# Speed: 10.0ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.6ms
# Speed: 10.0ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 ERs, 71.9ms
# Speed: 0.0ms preprocess, 71.9ms inference, 40.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 10.0ms preprocess, 50.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 cars, 1 truck, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 30.4ms
# Speed: 0.0ms preprocess, 30.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 40.9ms
# Speed: 10.2ms preprocess, 40.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
#
# 0: 320x640 2 cars, 1 truck, 30.6ms
# Speed: 0.0ms preprocess, 30.6ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 384x640 1 ER, 70.6ms
# Speed: 10.4ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 60.0ms
#
# Speed: 10.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 20.0ms
# Speed: 10.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
#
# 0: 384x640 (no detections), 20.5ms
# Speed: 10.2ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 ERs, 20.5ms
# Speed: 10.2ms preprocess, 20.5ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.5ms
# Speed: 10.1ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 ER, 60.3ms
# Speed: 0.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 30.8ms
# Speed: 10.0ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 ER, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 18.4ms
# Speed: 4.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 13.7ms
# Speed: 4.5ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 ER, 25.9ms
# 0: 320x640 2 cars, 1 truck, 31.8ms
# Speed: 8.0ms preprocess, 25.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 8.0ms preprocess, 31.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 ER, 25.4ms
# Speed: 3.6ms preprocess, 25.4ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 ER, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 24.3ms
# Speed: 10.0ms preprocess, 24.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
#
# 0: 384x640 1 ER, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 320x640 2 cars, 1 truck, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 cars, 1 truck, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 10.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.5ms
# Speed: 10.4ms preprocess, 16.5ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 11.5ms
# Speed: 5.6ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 13.8ms
# Speed: 0.5ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 43.5ms
# Speed: 8.0ms preprocess, 43.5ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 15.9ms
# Speed: 2.7ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.3ms
# Speed: 5.7ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 13.9ms
# Speed: 2.6ms preprocess, 13.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.4ms
# Speed: 4.5ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 13.8ms
# Speed: 0.0ms preprocess, 13.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.7ms
# Speed: 1.7ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.7ms
# Speed: 3.6ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 23.1ms
# Speed: 0.0ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 16.7ms
# Speed: 3.6ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 14.5ms
# Speed: 0.4ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 train, 1 truck, 18.3ms
# Speed: 5.7ms preprocess, 18.3ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 train, 1 truck, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 train, 1 truck, 10.1ms
# Speed: 8.0ms preprocess, 10.1ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.3ms
# Speed: 7.1ms preprocess, 18.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 bus, 1 truck, 19.0ms
# Speed: 5.3ms preprocess, 19.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 bus, 1 truck, 18.4ms
# Speed: 9.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 bus, 1 truck, 18.3ms
# Speed: 3.5ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 bus, 1 truck, 16.2ms
# Speed: 8.0ms preprocess, 16.2ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 23.2ms
# Speed: 0.0ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 22.0ms
# Speed: 2.8ms preprocess, 22.0ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 19.6ms
# Speed: 6.9ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 17.1ms
# Speed: 7.0ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 20.1ms
# Speed: 3.2ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 18.4ms
# Speed: 8.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# Changing to: North-South Left Turn Green

# %%
import numpy as np
import tensorflow as tf
from collections import deque
from traffic_count_detection import get_vehicle_counts_at_second
from emergency_detection import detect_emergency_at_second
from accident_detection import detect_accident_at_second

# Load the trained RL model
model = tf.keras.models.load_model("../models/rl_trained_model.keras")

# Phase encoding with four traffic phases
PHASE_ENCODING = {
    0: [1, 0, 0, 0],  # North-South Straight
    1: [0, 1, 0, 0],  # East-West Straight
    2: [0, 0, 1, 0],  # North-South Left Turn
    3: [0, 0, 0, 1],  # East-West Left Turn
}

def get_state(in_counts, out_counts, emergency, accident, queue_length, current_phase, phase_history, neighbor_state):
    in_counts = [count / 10.0 for count in in_counts]
    out_counts = [count / 10.0 for count in out_counts]
    neighbor_state = [count / 10.0 for count in neighbor_state]

    state = []
    state.extend(in_counts)
    state.extend(out_counts)
    state.extend([emergency, accident, queue_length])
    state.extend(PHASE_ENCODING[current_phase])
    state.extend(np.array(phase_history).flatten())  # Flatten phase history
    state.extend(neighbor_state)
    return np.array(state, dtype=np.float32)

def act(state, model):
    state = state.reshape(1, -1)
    q_values = model.predict(state, verbose=0)
    return np.argmax(q_values[0])

def get_inputs():
    # Define video paths
    video_paths = [
        '../videos/count/count_2.mp4',
        '../videos/count/count_4.mp4',
        '../videos/count/count_6.mp4',
        '../videos/count/count_7.mp4'
    ]

    # Initialize variables
    in_counts = []
    out_counts = []
    emergency_detected = False
    accident_detected = False

    # Define the target second for detection
    target_second = 10  # Specify the second for emergency and accident detection

    for path in video_paths:
        # Get vehicle counts
        in_count, out_count = get_vehicle_counts_at_second(path, target_second)
        in_counts.append(in_count)
        out_counts.append(out_count)

        # Check for emergency vehicles at the specified second
        if detect_emergency_at_second(path, target_second):
            emergency_detected = True

        # Check for accidents at the specified second
        if detect_accident_at_second(path, target_second):
            accident_detected = True

    # Set flags based on detection results
    emergency = 1 if emergency_detected else 0
    accident = 1 if accident_detected else 0

    # Calculate queue length
    queue_length = max(0, sum(in_counts) - sum(out_counts))  # Ensure non-negative value

    # Placeholder neighbor state
    neighbor_state = [0] * 8  # Modify as needed for neighbor data

    return in_counts, out_counts, emergency, accident, queue_length, neighbor_state

def change_phase(phase):
    phases = [
        "North-South Straight Traffic Green",
        "East-West Straight Traffic Green",
        "North-South Left Turn Green",
        "East-West Left Turn Green"
    ]
    print(f"Changing to: {phases[phase]}")

def main_inference():
    # Track last 3 phases
    phase_history = deque([[0, 0, 0, 0] for _ in range(3)], maxlen=3)
    current_phase = 0  # Initialize with phase 0

    # Get input data
    in_counts, out_counts, emergency, accident, queue_length, neighbor_state = get_inputs()

    # Prepare the state for RL model
    state = get_state(
        in_counts, out_counts, emergency, accident, queue_length,
        current_phase, phase_history, neighbor_state
    )

    # Predict the next phase using the RL model
    next_phase = act(state, model)
    change_phase(next_phase)

if __name__ == "__main__":
    main_inference()
# Out:
# 0: 320x640 2 persons, 6 cars, 91.9ms
# Speed: 0.0ms preprocess, 91.9ms inference, 87.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 60.2ms
# Speed: 0.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 10 cars, 1 train, 1 truck, 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 36.0ms
# Speed: 10.0ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 car, 81.2ms
# Speed: 15.6ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 97.1ms
# Speed: 0.0ms preprocess, 97.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.0ms
# Speed: 12.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 cars, 1 bus, 1 truck, 73.1ms
# Speed: 11.0ms preprocess, 73.1ms inference, 15.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 96.2ms
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 36.1ms
# Speed: 0.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Changing to: North-South Straight Traffic Green

# %%
import time

# Traffic Signal Optimization Function
def optimize_signals(in_count, out_count, emergency, accident, neighbor_states):
    """
    Optimize traffic signals for an intersection based on traffic conditions.

    Args:
        in_count (list): Traffic approaching each signal [South, North, East, West].
        out_count (list): Traffic exiting each signal [South, North, East, West].
        emergency (str): Direction of an emergency vehicle (South, North, East, West, or None).
        accident (str): Direction of an accident (South, North, East, West, or None).
        neighbor_states (list): Outbound traffic from neighboring intersections [South, North, East, West].

    Returns:
        dict: Signal states {"green": <direction>, "red": [<directions>]}.
    """
    # Define the directions and initialize priorities
    phases = ["South", "North", "East", "West"]
    priorities = []

    # Step 1: Emergency Handling
    if emergency in phases:
        return {"green": emergency, "red": [d for d in phases if d != emergency]}

    # Step 2: Calculate Priorities
    for i, phase in enumerate(phases):
        if phase == accident:
            priorities.append(-1)  # Exclude accident direction
        else:
            # Priority is based on in_count + weighted neighbor state
            priorities.append(in_count[i] + 0.5 * neighbor_states[i])

    # Step 3: Select the Phase with Highest Priority
    max_priority = max(priorities)
    if max_priority == -1:
        return None  # No valid phases available due to accidents
    selected_phase = phases[priorities.index(max_priority)]

    # Step 4: Set Signal States
    green = selected_phase
    red = [d for d in phases if d != green]
    return {"green": green, "red": red}


# Traffic Signal Control Simulation
def traffic_signal_control():
    """
    Simulate traffic signal control for an intersection with dynamic conditions.
    """
    # Example inputs
    in_count = [10, 15, 20, 5]  # Traffic approaching [South, North, East, West]
    out_count = [5, 10, 8, 12]  # Traffic exiting [South, North, East, West]
    neighbor_states = [7, 9, 5, 6]  # Outbound traffic from neighbors [South, North, East, West]

    # Dynamic conditions (can change during runtime)
    emergency = "None"  # Set to None or "South", "North", "East", "West"
    accident = "None"  # Set to None or "South", "North", "East", "West"

        # Optimize signals based on the current state
    signal_states = optimize_signals(in_count, out_count, emergency, accident, neighbor_states)

    if signal_states is None:
        print("No valid phases available. All signals remain red.")

    # Display the signal states
    print(f"Green Signal: {signal_states['green']}")
    print(f"Red Signals: {', '.join(signal_states['red'])}")
    print("-" * 50)


# Main Function
if __name__ == "__main__":
    traffic_signal_control()
# Out:
# Green Signal: East
# Red Signals: South, North, West
# --------------------------------------------------

# %%
import time
from collections import deque
import numpy as np
from traffic_count_detection import get_vehicle_counts_at_second
from emergency_detection import detect_emergency_at_second
from accident_detection import detect_accident_at_second


# Traffic Signal Optimization Function
def optimize_signals(in_count, out_count, emergency, accident, neighbor_states):
    phases = ["South", "North", "East", "West"]
    priorities = []

    # Step 1: Emergency Handling
    if emergency in phases:
        return {"green": emergency, "red": [d for d in phases if d != emergency]}

    # Step 2: Calculate Priorities
    for i, phase in enumerate(phases):
        if phase == accident:
            priorities.append(-1)  # Exclude accident direction
        else:
            priorities.append(in_count[i] + 0.5 * neighbor_states[i])

    # Step 3: Select the Phase with Highest Priority
    max_priority = max(priorities)
    if max_priority == -1:
        return None  # No valid phases available due to accidents
    selected_phase = phases[priorities.index(max_priority)]

    # Step 4: Set Signal States
    green = selected_phase
    red = [d for d in phases if d != green]
    return {"green": green, "red": red}


# Function to Get Inputs for a Specific Target Second
def get_inputs(target_second):
    # Get in/out counts from four different video streams
    in_counts = []
    out_counts = []

    # # Define video paths
    # video_paths = [
    #     '../videos/count/count_2.mp4',
    #     '../videos/count/count_4.mp4',
    #     '../videos/count/count_6.mp4',
    #     '../videos/count/count_7.mp4'
    # ]

    video_paths = [
        '../videos/cut/lane_1.mp4',
        '../videos/cut/lane_2.mp4',
        '../videos/cut/lane_3.mp4',
        '../videos/cut/lane_4.mp4'
    ]

    # Initialize flags
    emergency_detected = False
    accident_detected = False

    for path in video_paths:
        # Get vehicle counts at the target second
        in_count, out_count = get_vehicle_counts_at_second(path, target_second)
        in_counts.append(in_count)
        out_counts.append(out_count)

        # Check for emergency vehicles at the specified second
        if detect_emergency_at_second(path, target_second):
            emergency_detected = True

        # Check for accidents at the specified second
        if detect_accident_at_second(path, target_second):
            accident_detected = True

    # Set emergency and accident flags
    emergency = "None"
    accident = "None"

    # Placeholder neighbor states (this can be modified as needed)
    neighbor_states = [5, 7, 3, 4]

    return in_counts, out_counts, emergency, accident, neighbor_states


# Traffic Signal Control Simulation
def traffic_signal_control():
    # Track last 3 phases
    phase_history = deque([[0, 0, 0, 0] for _ in range(3)], maxlen=3)
    current_phase = 0  # Initialize with phase 0
    interval = 10  # Time interval in seconds to fetch data (10 seconds for this case)
    target_second = 10  # Initial second to analyze

    while True:
        # Get input data for the current target second
        in_counts, out_counts, emergency, accident, neighbor_state = get_inputs(target_second)

        # Optimize signals based on the current state
        signal_states = optimize_signals(in_counts, out_counts, emergency, accident, neighbor_state)

        if signal_states is None:
            print("No valid phases available. All signals remain red.")
        else:
            # Log and display the signal states
            print(f"Green Signal: {signal_states['green']}")
            print(f"Red Signals: {', '.join(signal_states['red'])}")
            print("-" * 50)

        # Update phase history and set the current phase
        phase_history.append([signal_states['green'] if signal_states else "None"] * 4)
        current_phase = signal_states['green'] if signal_states else current_phase

        # Update the target second for the next interval (move to the next 10th second)
        target_second += interval

        # Wait for the next interval
        time.sleep(interval)


# Main Function
if __name__ == "__main__":
    traffic_signal_control()
# Out:
# 0: 320x640 9 cars, 1 train, 1 truck, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 70.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 ER, 64.9ms
# Speed: 1.1ms preprocess, 64.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 41.6ms
# Speed: 0.0ms preprocess, 41.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 6 cars, 1 train, 3 trucks, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 11 cars, 2 trucks, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 8 cars, 1 train, 4.1ms
# Speed: 2.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 5.1ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 18.1ms
# Speed: 1.6ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Green Signal: South
# Red Signals: North, East, West
# --------------------------------------------------
#
# 0: 320x640 9 cars, 1 train, 3 trucks, 84.7ms
# Speed: 0.0ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 81.0ms
# Speed: 4.6ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 31.2ms
# Speed: 8.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 11 cars, 1 train, 2 trucks, 68.2ms
# Speed: 15.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 ERs, 71.2ms
# Speed: 9.0ms preprocess, 71.2ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 accident, 1 noaccident, 28.4ms
# Speed: 0.0ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 7 cars, 2 buss, 1 train, 2 trucks, 33.2ms
# Speed: 10.4ms preprocess, 33.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 9 cars, 1 train, 1 truck, 39.7ms
# Speed: 0.0ms preprocess, 39.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 38.2ms
# Speed: 0.0ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 noaccident, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
# Green Signal: South
# Red Signals: North, East, West
# --------------------------------------------------

# %%
from ultralytics import YOLO
import cv2

# Load the YOLOv8m model pre-trained on COCO (which includes the 'person' class)
model = YOLO("yolov8m.pt")

def detect_pedestrians(video_path, target_second, confidence_threshold=0.5, show_output=True):
    """
    Detect pedestrians in the given video at a specific second using YOLOv8m and visualize the output.

    Parameters:
        video_path (str): Path to the video file.
        target_second (int): The second at which to analyze the frame.
        confidence_threshold (float): Minimum confidence score to consider a detection valid.
        show_output (bool): Whether to display the detection output.

    Returns:
        bool: True if pedestrians are detected, False otherwise.
    """
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second of the video
    frame_number = int(target_second * fps)  # Calculate the frame number to extract
    
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)  # Jump to the target frame
    ret, frame = cap.read()

    if not ret:
        print(f"Error: Unable to read the frame at second {target_second}")
        cap.release()
        return False  # Return False if frame cannot be read

    # Perform pedestrian detection
    results = model(frame)  # YOLOv8 inference
    detections = results[0].boxes.data.cpu().numpy()  # Extract detections (bounding boxes, confidence, class IDs)
    
    person_detected = False
    for detection in detections:
        x1, y1, x2, y2, confidence, class_id = detection
        if int(class_id) == 0 and confidence >= confidence_threshold:  # Class ID 0 is 'person'
            person_detected = True
            # Draw the bounding box
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            label = f"Person: {confidence:.2f}"
            cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the frame with detections
    if show_output:
        cv2.imshow("Pedestrian Detection", frame)
        cv2.waitKey(0)  # Wait for a key press to close the window
        cv2.destroyAllWindows()

    cap.release()  # Release video resource
    return person_detected

# %%
# Example usage
video_path = "../videos/pedestrians/lane_1.mp4"
target_second = 10  # Analyze the video at the 10th second
pedestrian_present = detect_pedestrians(video_path, target_second)

if pedestrian_present:
    print("Pedestrians detected. Activate green signal.")
else:
    print("No pedestrians detected. Keep signal red.")
# Out:
# 0: 384x640 24 persons, 2 handbags, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Pedestrians detected. Activate green signal.

# %%
import cv2
from ultralytics import YOLO
from tracker import Tracker

# Initialize YOLO model
model = YOLO('../models/yolov8m.pt')

# Function to process video and return pedestrian counts at a specific second
def get_pedestrian_counts_at_second(video_path, target_second=20):
    tracker = Tracker()
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return 0, 0

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    target_frame = target_second * fps
    in_count, out_count = 0, 0
    in_ids, out_ids = set(), set()

    cap.set(cv2.CAP_PROP_POS_FRAMES, target_frame)

    ret, frame = cap.read()
    if not ret:
        print(f"Failed to read the frame at second {target_second}. Returning counts as (0, 0).")
        cap.release()
        return 0, 0

    resized_width, resized_height = 1020, 500
    frame = cv2.resize(frame, (resized_width, resized_height))

    # Define the vertical counting lines for pedestrian crossing areas
    vertical_line_x_left = resized_width // 4  # Left side of the pedestrian crossing area
    vertical_line_x_right = 3 * resized_width // 4  # Right side of the pedestrian crossing area

    results = model.predict(frame)
    objects_rects = []

    for result in results:
        for box in result.boxes.data.cpu().numpy():
            x1, y1, x2, y2, conf, class_id = map(float, box[:6])
            # If detected class is pedestrian (class_id of pedestrian in YOLO is typically 0 or 1)
            if class_id == 0:  # Change based on the class ID for pedestrians in your model
                objects_rects.append([x1, y1, x2 - x1, y2 - y1])

    bbox_ids = tracker.update(objects_rects)

    for bbox in bbox_ids:
        x, y, w, h, obj_id = bbox
        cx, cy = x + w // 2, y + h // 2  # Calculate the center of the bounding box

        # Check if pedestrian is on the left or right side of the pedestrian crossing area
        if cx < vertical_line_x_left:
            if obj_id not in out_ids:  # Pedestrian crossing from left
                out_count += 1
                out_ids.add(obj_id)
        elif cx > vertical_line_x_right:
            if obj_id not in in_ids:  # Pedestrian crossing from right
                in_count += 1
                in_ids.add(obj_id)

        # Draw bounding box and vertical lines for visualization
        cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {obj_id}", (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical lines for left and right pedestrian crossing areas
    cv2.line(frame, (vertical_line_x_left, 0), (vertical_line_x_left, resized_height), (255, 0, 0), 2)
    cv2.line(frame, (vertical_line_x_right, 0), (vertical_line_x_right, resized_height), (255, 0, 0), 2)

    # Optionally, display the processed frame
    cv2.imshow("Pedestrian Detection at Target Second", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cap.release()

    # Return counts
    return in_count, out_count

# Test with a video
video_path = "../videos/cut/lane_1.mp4"
in_count, out_count = get_pedestrian_counts_at_second(video_path, target_second=10)
print(f"Left count: {in_count}, Right count: {out_count}")
# Out:
# 0: 320x640 9 cars, 1 truck, 25.4ms
# Speed: 0.0ms preprocess, 25.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# Left count: 0, Right count: 0

# %%
import cv2
from ultralytics import YOLO
from tracker import Tracker

# Initialize YOLO model
model = YOLO('../models/yolov8m.pt')

# Function to process video and return pedestrian counts at a specific second
def get_pedestrian_counts_at_second(video_path, target_second=20):
    tracker = Tracker()
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return 0, 0

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    target_frame = target_second * fps
    in_count, out_count = 0, 0
    in_ids, out_ids = set(), set()

    cap.set(cv2.CAP_PROP_POS_FRAMES, target_frame)

    ret, frame = cap.read()
    if not ret:
        print(f"Failed to read the frame at second {target_second}. Returning counts as (0, 0).")
        cap.release()
        return 0, 0

    resized_width, resized_height = 1020, 500
    frame = cv2.resize(frame, (resized_width, resized_height))

    # Define the vertical counting lines for pedestrian crossing areas (closer to left and right)
    vertical_line_x_left = int(resized_width * 0.1)  # 20% from the left side of the frame
    vertical_line_x_right = int(resized_width * 0.9)  # 80% from the left side of the frame

    results = model.predict(frame)
    objects_rects = []

    for result in results:
        for box in result.boxes.data.cpu().numpy():
            x1, y1, x2, y2, conf, class_id = map(float, box[:6])
            # If detected class is pedestrian (class_id of pedestrian in YOLO is typically 0 or 1)
            if class_id == 0:  # Change based on the class ID for pedestrians in your model
                objects_rects.append([x1, y1, x2 - x1, y2 - y1])

    bbox_ids = tracker.update(objects_rects)

    for bbox in bbox_ids:
        x, y, w, h, obj_id = bbox
        cx, cy = x + w // 2, y + h // 2  # Calculate the center of the bounding box

        # Check if pedestrian is on the left or right side of the pedestrian crossing area
        if cx < vertical_line_x_left:
            if obj_id not in out_ids:  # Pedestrian crossing from left
                out_count += 1
                out_ids.add(obj_id)
        elif cx > vertical_line_x_right:
            if obj_id not in in_ids:  # Pedestrian crossing from right
                in_count += 1
                in_ids.add(obj_id)

        # Draw bounding box and vertical lines for visualization
        cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {obj_id}", (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical lines for left and right pedestrian crossing areas
    cv2.line(frame, (vertical_line_x_left, 0), (vertical_line_x_left, resized_height), (255, 0, 0), 2)
    cv2.line(frame, (vertical_line_x_right, 0), (vertical_line_x_right, resized_height), (255, 0, 0), 2)

    # Optionally, display the processed frame
    cv2.imshow("Pedestrian Detection at Target Second", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cap.release()

    # Return counts
    return in_count, out_count

# Test with a video
video_path = "../videos/cut/lane_1.mp4"
in_count, out_count = get_pedestrian_counts_at_second(video_path, target_second=10)
print(f"Left count: {in_count}, Right count: {out_count}")
# Out:
# 0: 320x640 9 cars, 1 truck, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# Left count: 0, Right count: 0
